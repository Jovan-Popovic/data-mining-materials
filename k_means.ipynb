# %%
import numpy as np
from algorithms.k_means import kmeans_fit, plot_clusters, elbow_plot, predict

# 3 “prirodna” klastera – 2-D
np.random.seed(42)
A = np.random.randn(50, 2) * 0.6 + [1, 1]
B = np.random.randn(50, 2) * 0.5 + [5, 4]
C = np.random.randn(50, 2) * 0.4 + [1, 5]
X = np.vstack([A, B, C])

# %%
elbow_plot(X, range(1, 8), init="k++")
# Out:
# iter 1    SSE=537.9306
#           max centroid shift = 1.397622
# iter 2    SSE=374.8667
#           max centroid shift = 0.256963
# iter 3    SSE=372.9702
#           max centroid shift = 0.078515
# iter 4    SSE=372.5450
#           max centroid shift = 0.092630
# iter 5    SSE=372.0282
#           max centroid shift = 0.083350
# iter 6    SSE=371.6746
#           max centroid shift = 0.079483
# iter 7    SSE=371.5370
#           max centroid shift = 0.000000
# ⇣  converged (shift ≤ tol)

# %%
k = 3
C, labels, sse_hist = kmeans_fit(X, k, verbose=True, init="k++")

# finalni graf
plot_clusters(X, C, labels, title=f"k={k} (SSE={sse_hist[-1]:.1f})")

# %%
new_pt = np.array([[2.0, 4.0]])
lbl = predict(new_pt, C)[0]
print("Nova tačka", new_pt[0], "→ cluster", lbl)
