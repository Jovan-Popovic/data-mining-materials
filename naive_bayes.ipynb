# %%
from algorithms.naive_bayes import naive_bayes_train, plot_priors
from pandas import DataFrame

data = [
    ["DA", "DA", "DA", "i5", 8, "DA"],
    ["DA", "DA", "NE", "i3", 4, "NE"],
    ["NE", "NE", "NE", "i7", 2, "DA"],
    ["NE", "DA", "DA", "i3", 6, "NE"],
    ["NE", "NE", "DA", "i7", 8, "NE"],
    ["DA", "NE", "DA", "i5", 2, "DA"],
    ["DA", "DA", "DA", "i3", 4, "DA"],
    ["NE", "NE", "NE", "i5", 8, "NE"],
]
cols = ["Ima zahtjev", "Garancija", "Cesti problemi", "Procesor", "RAM", "Treba mijenjati"]
df = DataFrame(data, columns=cols)

categorical_cols = ["Ima zahtjev", "Garancija", "Cesti problemi", "Procesor"]
numeric_cols = ["RAM"]
target_col = "Treba mijenjati"

model = naive_bayes_train(df, target_col, categorical_cols, numeric_cols)
plot_priors(model)
